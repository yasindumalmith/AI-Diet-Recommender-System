# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'yasindumalmith', 'key': 'KGAT_c36133c1dc556b206b3df5c2317b4d23'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Using cached kaggle-1.8.2-py3-none-any.whl.metadata (16 kB)
# Collecting black>=24.10.0 (from kaggle)
#   Using cached black-25.12.0-cp313-cp313-win_amd64.whl.metadata (86 kB)
# Requirement already satisfied: bleach in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from kaggle) (6.3.0)
# Collecting kagglesdk (from kaggle)
#   Using cached kagglesdk-0.1.13-py3-none-any.whl.metadata (13 kB)
# Collecting mypy>=1.15.0 (from kaggle)
#   Using cached mypy-1.19.0-cp313-cp313-win_amd64.whl.metadata (2.2 kB)
# Collecting protobuf (from kaggle)
#   Using cached protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Using cached python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from kaggle) (1.17.0)
# Collecting tqdm (from kaggle)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting types-requests (from kaggle)
#   Using cached types_requests-2.32.4.20250913-py3-none-any.whl.metadata (2.0 kB)
# Collecting types-tqdm (from kaggle)
#   Using cached types_tqdm-4.67.0.20250809-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3>=1.15.1 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from kaggle) (2.6.2)
# Collecting click>=8.0.0 (from black>=24.10.0->kaggle)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting mypy-extensions>=0.4.3 (from black>=24.10.0->kaggle)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from black>=24.10.0->kaggle) (25.0)
# Collecting pathspec>=0.9.0 (from black>=24.10.0->kaggle)
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Collecting pytokens>=0.3.0 (from black>=24.10.0->kaggle)
#   Using cached pytokens-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: colorama in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Collecting librt>=0.6.2 (from mypy>=1.15.0->kaggle)
#   Using cached librt-0.7.3-cp313-cp313-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: webencodings in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from bleach->kaggle) (0.5.1)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\university academic\3rd year\2nd sem\ai\diet recommender system\ai-diet-recommender-system\env\lib\site-packages (from requests->kaggle) (2025.11.12)
# Using cached kaggle-1.8.2-py3-none-any.whl (256 kB)
# Using cached black-25.12.0-cp313-cp313-win_amd64.whl (1.4 MB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached mypy-1.19.0-cp313-cp313-win_amd64.whl (10.1 MB)
# Using cached librt-0.7.3-cp313-cp313-win_amd64.whl (54 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Using cached pytokens-0.3.0-py3-none-any.whl (12 kB)
# Using cached kagglesdk-0.1.13-py3-none-any.whl (159 kB)
# Using cached protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Using cached python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached types_requests-2.32.4.20250913-py3-none-any.whl (20 kB)
# Using cached types_tqdm-4.67.0.20250809-py3-none-any.whl (24 kB)
# Installing collected packages: text-unidecode, types-requests, tqdm, pytokens, python-slugify, protobuf, pathspec, mypy-extensions, librt, click, types-tqdm, mypy, kagglesdk, black, kaggle
#
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    -------- -------------------------------  3/15 [pytokens]
#    ---------- -----------------------------  4/15 [python-slugify]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ---------------- -----------------------  6/15 [pathspec]
#    ---------------- -----------------------  6/15 [pathspec]
#    ------------------------ ---------------  9/15 [click]
#    ------------------------ ---------------  9/15 [click]
#    ------------------------ ---------------  9/15 [click]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ---------------------------------------- 15/15 [kaggle]
#
# Successfully installed black-25.12.0 click-8.3.1 kaggle-1.8.2 kagglesdk-0.1.13 librt-0.7.3 mypy-1.19.0 mypy-extensions-1.1.0 pathspec-0.12.1 protobuf-6.33.2 python-slugify-8.0.4 pytokens-0.3.0 text-unidecode-1.3 tqdm-4.67.1 types-requests-2.32.4.20250913 types-tqdm-4.67.0.20250809

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('rukenmissonnier/age-weight-height-bmi-analysis', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rukenmissonnier/age-weight-height-bmi-analysis

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import zipfile
# ----> 2 with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
#       3     zip_ref.extractall('../artifacts/')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py:1362, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1360 while True:
#    1361     try:
# -> 1362         self.fp = io.open(file, filemode)
#    1363     except OSError:
#    1364         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../artifacts/sentiment-analysis-dataset.zip'

# %%
import zipfile
with zipfile.ZipFile('../artifacts/age-weight-height-bmi-analysis.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
